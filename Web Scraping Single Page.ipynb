# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
r = requests.get('https://www.billboard.com/charts/hot-100/')

# %%
r.status_code
# Out:
# 200

# %%
html = r.content

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
html_songs = soup.find_all('h3', attrs={'id': 'title-of-a-story'})

# %%
html_top1 = soup.find_all('span', attrs={'class': 'c-label a-no-trucate a-font-primary-s \
lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 \
lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet'})

# %%
html_top1
# Out:
# [<span class="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet">
#
#  	Ariana Grande
#  </span>]

# %%
html_artists = soup.find_all('span', attrs={'class': 'c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max \
u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 \
u-max-width-230@tablet-only'})

# %%
html_first = soup.find_all('li', attrs={'class': 'o-chart-results-list__item // lrv-u-flex-grow-1 lrv-u-flex \
lrv-u-flex-direction-column lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max \
lrv-u-border-color-grey-light lrv-u-padding-l-1@mobile-max'})

# %%
html_rest = soup.find_all('li', attrs={'class': 'o-chart-results-list__item // lrv-u-flex-grow-1 lrv-u-flex \
lrv-u-flex-direction-column lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light \
lrv-u-padding-l-050 lrv-u-padding-l-1@mobile-max'})

# %%
html_complete = html_first + html_rest

# %%
song = []
artist = []

for entry in html_complete:
    song.append(entry.find("h3").get_text().replace("\n", "").replace('\t', ''))
    artist.append(entry.find("span").get_text().replace("\n", "").replace('\t', ''))

# Here we ensamble the DataFrame
top100 = pd.DataFrame()
top100['song'] = song
top100['artist'] = artist
top100
# Out:
#                                         song  \
# 0   We Can't Be Friends (Wait For Your Love)
# 1                               Lose Control
# 2                           Beautiful Things
# 3                                   Carnival
# 4                                Lovin On Me
# ..                                       ...
# 95                       Back Then Right Now
# 96                                Tourniquet
# 97                                 Outskirts
# 98                                  Worth It
# 99                                  Fuk Sumn
#
#                                                artist
# 0                                       Ariana Grande
# 1                                         Teddy Swims
# 2                                        Benson Boone
# 3   ¥$: Ye & Ty Dolla $ign Featuring Rich The Kid ...
# 4                                         Jack Harlow
# ..                                                ...
# 95                                      Tyler Hubbard
# 96                                         Zach Bryan
# 97                                           Sam Hunt
# 98                               Offset & Don Toliver
# 99                             ¥$: Ye & Ty Dolla $ign
#
# [100 rows x 2 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
top100
# Out:
#                                                  song  \
# 0            We Can't Be Friends (Wait For Your Love)
# 1                                        Lose Control
# 2                                    Beautiful Things
# 3                                            Carnival
# 4                                         Lovin On Me
# 5                                      Texas Hold 'Em
# 6                                    Act II: Date @ 8
# 7                                              Greedy
# 8                               I Remember Everything
# 9                                           Yes, And?
# 10                                             Snooze
# 11                                        Agora Hills
# 12                                       Cruel Summer
# 13                                             Saturn
# 14                                       Stick Season
# 15                                    The Boy Is Mine
# 16                                       Supernatural
# 17                                         Last Night
# 18                                              Water
# 19                                           Fast Car
# 20                                   End Of Beginning
# 21                                             Redrum
# 22                                   Eternal Sunshine
# 23                                 Whatever She Wants
# 24                                                Bye
# 25                                   Thinkin' Bout Me
# 26  Is It Over Now? (Taylor's Version) [From The V...
# 27                         Don't Wanna Break Up Again
# 28                                        Made For Me
# 29                                         True Story
# 30                                            Houdini
# 31                                 Paint The Town Red
# 32                                            Feather
# 33                                      Never Lose Me
# 34                               What Was I Made For?
# 35                                          Truck Bed
# 36                                  Imperfect For You
# 37                           Intro (End Of The World)
# 38                                 I Wish I Hated You
# 39                                            Selfish
# 40                                          Yeah Glo!
# 41                               Pretty Little Poison
# 42                                          Wild Ones
# 43                                          La Diabla
# 44                                            Save Me
# 45                          Where The Wild Things Are
# 46                                               Exes
# 47                                            Vampire
# 48                                        The Painter
# 49                                               FE!N
# 50                                     Man Made A Bar
# 51                                                 23
# 52                                       Burn It Down
# 53                                      I Can Feel It
# 54                                    Ordinary Things
# 55                        Wildflowers And Wild Horses
# 56                        Praise Jah In The Moonlight
# 57                                      Mamaw's House
# 58                                          Everybody
# 59                                      World On Fire
# 60                                     Surround Sound
# 61                                          Soak City
# 62                                     Get In With Me
# 63                                   One Of The Girls
# 64                                            Breathe
# 65                                 You Broke My Heart
# 66                                    Scared To Start
# 67                                    Training Season
# 68                           Murder On The Dancefloor
# 69                                           One Call
# 70                                               FTCU
# 71                                        Sensational
# 72                                      Where It Ends
# 73                                             Austin
# 74                                            Tu Name
# 75                                         La Victima
# 76                             Spin You Around (1/24)
# 77                                             Bandit
# 78                                 Oklahoma Smokeshow
# 79                                              Mmhmm
# 80                                       Harley Quinn
# 81                                        Perro Negro
# 82                                               Home
# 83                              Like What (Freestyle)
# 84                                            Nee-nah
# 85                                           Bellakeo
# 86                                        Holy Smokes
# 87                               Standing Next To You
# 88                                           Let's Go
# 89                                               Coal
# 90                                               Burn
# 91                                    Tucson Too Late
# 92                                            Contigo
# 93                                 Igual Que Un Angel
# 94                                            My Eyes
# 95                                Back Then Right Now
# 96                                         Tourniquet
# 97                                          Outskirts
# 98                                           Worth It
# 99                                           Fuk Sumn
#
#                                                artist
# 0                                       Ariana Grande
# 1                                         Teddy Swims
# 2                                        Benson Boone
# 3   ¥$: Ye & Ty Dolla $ign Featuring Rich The Kid ...
# 4                                         Jack Harlow
# 5                                             Beyonce
# 6                               4Batz Featuring Drake
# 7                                          Tate McRae
# 8                Zach Bryan Featuring Kacey Musgraves
# 9                                       Ariana Grande
# 10                                                SZA
# 11                                           Doja Cat
# 12                                       Taylor Swift
# 13                                                SZA
# 14                                         Noah Kahan
# 15                                      Ariana Grande
